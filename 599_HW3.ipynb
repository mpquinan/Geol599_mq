# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# %%
AQS = pd.read_csv('LA_AQS_2023.csv')

# %%
AQS = AQS.rename(columns = {'Parameter Name':'parameter', 'Duration Description':'duration', 'Date (Local)':'date', 'Arithmetic Mean':'mean'})

# %%
Oz_AQS = AQS.query('parameter == "Ozone" and duration == "1 HOUR"')

# %%
Oz_AQS.head()
# Out:
#      State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 20            6           37         1103           44201    1  34.06659
# 64            6           37         1103           44201    1  34.06659
# 204           6           37         1103           44201    1  34.06659
# 228           6           37         1103           44201    1  34.06659
# 271           6           37         1103           44201    1  34.06659
#
#      Longitude  Datum parameter duration  ... AQI Daily Criteria Indicator  \
# 20  -118.22688  WGS84     Ozone   1 HOUR  ...   .                        Y
# 64  -118.22688  WGS84     Ozone   1 HOUR  ...   .                        Y
# 204 -118.22688  WGS84     Ozone   1 HOUR  ...   .                        Y
# 228 -118.22688  WGS84     Ozone   1 HOUR  ...   .                        Y
# 271 -118.22688  WGS84     Ozone   1 HOUR  ...   .                        Y
#
#      Tribe Name  State Name  County Name    City Name  \
# ...

# %%
fig, o = plt.subplots(figsize=(8, 6))
o = sns.scatterplot(x="date", y="mean", data=Oz_AQS,)
o.set(xlabel='Date', ylabel='Nitrogen Dioxide (ppb)')
month_locator = mdates.MonthLocator(interval=1) 
o.xaxis.set_major_locator(month_locator)
fig.autofmt_xdate()

# %%
Oz35_AQS = Oz_AQS.query('mean > 0.035')

# %%
Oz35_AQS
# Out:
#        State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 4651            6           37         1103           44201    1  34.06659
# 4928            6           37         1103           44201    1  34.06659
# 5235            6           37         1103           44201    1  34.06659
# 7130            6           37         1103           44201    1  34.06659
# 7337            6           37         1103           44201    1  34.06659
# 7679            6           37         1103           44201    1  34.06659
# 7883            6           37         1103           44201    1  34.06659
# 8427            6           37         1103           44201    1  34.06659
# 8447            6           37         1103           44201    1  34.06659
# 9439            6           37         1103           44201    1  34.06659
# 9646            6           37         1103           44201    1  34.06659
# ...

# %% [markdown]
# Number of days Ozone > 35 ppm = 43

# %%
Oz_max = Oz_AQS.query('mean == mean.max()')

# %%
Oz_max['date']
# Out:
# 12292    2023-05-14
# Name: date, dtype: object

# %% [markdown]
# Highest Ozone = May 14, 2023

# %%
N_AQS = AQS.query('parameter == "Nitrogen dioxide (NO2)" and duration == "1 HOUR"')

# %%
fig, n = plt.subplots(figsize=(8, 6))
n = sns.scatterplot(x="Date (Local)", y="Arithmetic Mean", data=N_AQS,)
n.set(xlabel='Date', ylabel='Nitrogen Dioxide (ppb)')
month_locator = mdates.MonthLocator(interval=1) 
n.xaxis.set_major_locator(month_locator)
fig.autofmt_xdate()
